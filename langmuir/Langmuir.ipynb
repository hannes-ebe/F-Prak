# %% [markdown]
# # Langmuir-Sonden

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Betrachtung der Entladungskurve:

# %%
R = 1e3
U_0 = np.array([60.,70.0,80.0,90.0,95.0,100.0,102.5,105.0,110.0,115.0,110.0,115.0,120.0,125.0,120.0,115.0,110.0,105.0,102.5,100.0,95.0,90.0,85.0,82.5,80.0,75.0,70.0])
U_Roehre = np.array([60.0,70.,80.,90.,95.,81.2,81.9,80.6,79.9,76.4,76.4,76.6,76.9,76.6,76.3,76.1,75.9,75.9,76.0,76.2,76.5,78.1,82.2,82.3,80.0,75.0,70.])
U_R = np.array([0.,0.,0.,0.,0.,18.9,20.5,24.4,30.1,38.6,43.5,48.3,52.9,48.3,43.6,38.1,34.0,29.0,26.4,23.3,18.4,11.9,3.0,0.3,0.,0.,0.])
I_R = U_R/R
print(I_R)
# Out:
# [0.     0.     0.     0.     0.     0.0189 0.0205 0.0244 0.0301 0.0386
#  0.0435 0.0483 0.0529 0.0483 0.0436 0.0381 0.034  0.029  0.0264 0.0233
#  0.0184 0.0119 0.003  0.0003 0.     0.     0.    ]

# %%
ax = plt.subplots()

plt.plot(I_R,U_Roehre)
plt.xlabel('Entladungsstrom $I_R$ in A')
plt.ylabel('Röhrenspannung $U_{Röhre}$ in V')
plt.grid()

# %%
ax = plt.subplots()

plt.plot(U_0,U_Roehre)
plt.xlabel('Gesamtspannung $U_0$ in V')
plt.ylabel('Röhrenspannung $U_{Röhre}$ in V')
plt.grid()

# %%
ax = plt.subplots()

plt.plot(U_0,I_R)
plt.xlabel('Gesamtspannung $U_0$ in V')
plt.ylabel('Entladungsstrom $I_R$ in A')
plt.grid()

# %%
ax = plt.subplots()

plt.plot(U_Roehre,I_R)
plt.xlabel('Gesamtspannung $U_{Röhre}$ in V')
plt.ylabel('Entladungsstrom $I_R$ in A')
plt.grid()
